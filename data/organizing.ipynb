# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Private_Schools.csv')

# %%
data.head()
# Out:
#               X             Y  FID  OBJECTID    NCESID  \
# 0 -8.136078e+06  5.055506e+06    1      1201  A0507274
# 1 -8.147300e+06  5.037067e+06    2      1202  A0500844
# 2 -8.197042e+06  5.018050e+06    3      1203  A0108054
# 3 -8.171504e+06  5.077291e+06    4      1204  A0507283
# 4 -8.197596e+06  5.017131e+06    5      1205  01612613
#
#                                NAME                   ADDRESS        CITY  \
# 0                  A CHILD'S GARDEN           20 IVY BROOK RD     SHELTON
# 1  BRIDGEPORT INTERNATIONAL ACADEMY  285 LAFAYETTE ST STE 200  BRIDGEPORT
# 2                    CARMEL ACADMEY              270 LAKE AVE   GREENWICH
# 3                 COUNTRY KIDS CLUB           94 OLD STATE RD  BROOKFIELD
# 4                 EAGLE HILL SCHOOL           45 GLENVILLE RD   GREENWICH
#
#   STATE   ZIP  ...           SOURCEDATE     VAL_METHOD             VAL_DATE  \
# 0    CT  6484  ...  2010/01/29 00:00:00        IMAGERY  2010/02/25 00:00:00
# ...

# %%
data = data.drop(
    labels=["FID","OBJECTID", "NCESID", "STATE", "SOURCEDATE", "VAL_DATE", "WEBSITE", 
    "LEVEL_", "ENROLLMENT", "START_GRAD", "END_GRADE", "FT_TEACHER", "SHELTER_ID"], 
    axis=1)

# %%
data.head()
# Out:
#               X             Y                              NAME  \
# 0 -8.136078e+06  5.055506e+06                  A CHILD'S GARDEN
# 1 -8.147300e+06  5.037067e+06  BRIDGEPORT INTERNATIONAL ACADEMY
# 2 -8.197042e+06  5.018050e+06                    CARMEL ACADMEY
# 3 -8.171504e+06  5.077291e+06                 COUNTRY KIDS CLUB
# 4 -8.197596e+06  5.017131e+06                 EAGLE HILL SCHOOL
#
#                     ADDRESS        CITY   ZIP           ZIP4      TELEPHONE  \
# 0           20 IVY BROOK RD     SHELTON  6484           6418  NOT AVAILABLE
# 1  285 LAFAYETTE ST STE 200  BRIDGEPORT  6604           5755  NOT AVAILABLE
# 2              270 LAKE AVE   GREENWICH  6830           4518  NOT AVAILABLE
# 3           94 OLD STATE RD  BROOKFIELD  6804           2524  NOT AVAILABLE
# 4           45 GLENVILLE RD   GREENWICH  6831  NOT AVAILABLE  NOT AVAILABLE
#
#    TYPE  STATUS  POPULATION     COUNTY  COUNTYFIPS COUNTRY   LATITUDE  \
# ...

# %%
new_data = pd.DataFrame({
    'NAME': data['NAME'],
    'LATITUDE': data['LATITUDE'],
    'LONGITUDE': data['LONGITUDE']
    })

# %%
new_data.shape
# Out:
# (31064, 3)

# %%
new_data.to_csv('privateSchool.csv', sep='\t', encoding='utf-8')
